# %% [markdown]
# # Đề thi
# ## Câu 1 (2đ)
# Có 3 nhà máy cung cấp sản phẩm ra thị trường, trong đó nhà máy 1 chiếm 35%, nhà máy 2 chiếm 25% và nhà máy 3 chiém 40% tổng sản phẩm trên thị trường.
# Biết tỷ lệ phế phẩm của nhà máy 1 là 1%, nhà máy 2 là 2% và nhà máy 3 là 3%.
# Lấy ngẫu nhiên ra một sản phẩm. Tính xác suất để sản phẩm lấy được là chính phẩm.
#
# ## Câu 2 (1đ)
# Một hộp có 12 chiếc bút trong đó có 3 bút đỏ, 9 bút xanh. Lấy ngẫu nhiên ra 3 bút. Đặt $X$ là số bút đỏ lấy ra.
#   * Tính $P\left(X = 2\right)$
#   * Tính $EX$ và $E\left(4X - 1\right)$
#
# ## Câu 3 (2đ)
# Cho hàm mật độ đồng thời
# $f\left( {x,y} \right) = \begin{cases}
# {A\left( {3xy + 4y} \right)}& \text{nếu } {\left( {x,y} \right) \in \left[ {0,2} \right] \times \left[ {0,4} \right]}\\
# 0 & \text{nếu } {\left( {x,y} \right) \notin \left[ {0,2} \right] \times \left[ {0,4} \right]}
# \end{cases}$
#   * Tính $E\left( {3X + 2} \right)$
#   * Tính $P\left( {Y > 2\mid X < 1} \right)$
#
# ## Câu 4 (2.5đ)
# Điểm thi Toeic của sinh viên là đại lượng ngẫu nhiên có phân bố chuẩn. Thống kê điểm thi của một lớp 50 sinh viên, ta có số liệu
# <center>
#
# | $X$ (điểm thi) | 450 - 470 | 470 - 490 | 490 - 510 | 510 - 540 | 540 - 600 |
# | :-: | :-: | :-: | :-: | :-: | :-: |
# | $n_i$ | 4 | 15 | 13 | 12 | 6 |
# </center>
#
# Với độ tin cậy 85% hãy ước lượng điểm Toeic trung bình của sinh viên?
#
# ## Câu 5 (2.5đ)
# Tỷ lệ sinh viên bị điểm F môn xác suất thống kê hàng năm là 30%. Năm nay tỷ lệ điểm F có thể cao hơn. Hãy kiểm định nhận định trên với mức ý nghĩa 1%, biết rằng cho ngẫu nhiên 200 sinh viên thi thử thì có 62 sinh vien bị điểm F

# %% [markdown]
# # Đáp án
# ## Câu 1 (2đ)
# * $H_i = $ {sản phẩm lấy được do nhà máy $i$ sản xuất}, $i = 1, 2, 3$
# <span style="float: right;">0.5đ</span>
#
# $P\left( {{H_1}} \right) = $ tỷ lệ sản phẩm của nhà máy 1 = 0.35
#
# $P\left( {{H_2}} \right) = 0.25$, $P\left( {{H_3}} \right) = 0.4$
#
# * $A = $ {sản phẩm lấy được là chính phẩm}
# <span style="float: right;">0.5đ</span>
#
# $P\left( {A\mid{H_1}} \right) = $ tỷ lệ chính phẩm trong số các sản phẩm của nhà máy 1 $= 1 - 1\% = 0.99$
#
# $P\left( {A\mid {H_2}} \right) = 0.98$, $P\left( {A\mid{H_2}} \right) = 0.97$
#
# * $\displaystyle P\left( A \right) = \sum\limits_{i = 1}^3 {P\left( {{H_i}} \right) \times P\left( {A|{H_i}} \right)}  = 0.9795$
# <span style="float: right;">0.5đ + 0.5đ</span>
# ```mathematica
# 0.35*0.99 + 0.25*0.98 + 0.4*0.97
# ```

# %% [markdown]
# ## Câu 2 (1đ)
# * $P\left( {X = 2} \right) = \dfrac{{C_3^2 \times C_9^1}}{{C_{12}^3}} = \dfrac{{27}}{{220}} = 0.1227$
# <span style="float: right;">0.5đ</span>
# ```{mathematica, caption="Mathematica"}
# p = Binomial[3, 2]*Binomial[9, 1]/Binomial[12, 3]
# p // N
# ```
# * $P\left( {X = k} \right) = \dfrac{{C_3^k \times C_9^{3 - k}}}{{C_{12}^3}}$, $k = \overline{0, 3}$
# <span style="float: right;">0.25đ + 0.25đ</span>
# <center>
#
# | $X$ | 0 | 1 | 2 | 3 |
# | :-: | :-: | :-: | :-: | :-: |
# | $P$ | $\dfrac{21}{55}$ | $\dfrac{27}{55}$ | $\dfrac{27}{220}$ | $\dfrac{1}{220}$ |
# | $P$ | 0.3818 | 0.4909 | 0.1227 | 0.004545 |
# </center>
#
# ```mathematica
# P = Table[Binomial[3, k]*Binomial[9, 3 - k]/Binomial[12, 3], {k, 0, 3}]
# ```
#
# $\displaystyle EX = \sum\limits_{k = 0}^3 {k \times P\left( {X = k} \right)}  = \sum\limits_{k = 0}^3 {k \times \frac{{C_3^k \times C_9^{3 - k}}}{{C_{12}^3}}}  = \dfrac{3}{4}$
#
# $E\left( {4X - 1} \right) = 4 \times EX - 1 = 4 \times \dfrac{3}{4} - 1 = 2$
# ```mathematica
# X = {0, 1, 2, 3}
# e = X.P
# 4 e - 1
# ```

# %% [markdown]
# ## Câu 3 (2đ)
# $\displaystyle  \iint\limits_{{\Bbb R^2}} {f\left( {x,y} \right)dxdy} = 1 \Rightarrow 112A = 1 \Rightarrow A = \frac{1}{{112}} = 0.008929$
# <span style="float: right;">0.5đ</span>
# ```mathematica
# f[x_, y_] := If[0 <= x <= 2 && 0 <= y <= 4, A (3*x*y + 4*y), 0]
# Integrate[f[x, y], {x, -Infinity, Infinity}, {y, -Infinity, Infinity}]
# A = 1/112
# A // N
# ```
#
# * $\displaystyle E\left( {3X + 2} \right) = \iint\limits_{{\Bbb R^2}} {\left( {3x + 2} \right) \times f\left( {x,y} \right)dxdy} = \dfrac{38}{7} = 5.429$
# <span style="float: right;">0.5đ</span>
# ```mathematica
# e = Integrate[(3 x + 2) f[x, y], {x, -Infinity, Infinity}, {y, -Infinity, Infinity}]
# e // N
# ```
#
# * $p = \displaystyle P\left( {Y > 2\mid X < 1} \right) = \frac{{P\left( {Y > 2,X < 1} \right)}}{{P\left( {X < 1} \right)}} = \frac{t}{m}$
# <span style="float: right;">0.5đ</span>
#
# $m = \displaystyle P\left( X < 1 \right) = \int_{- \infty}^1 {dx\int_{- \infty}^{\infty} {f\left( {x,y} \right)dy} }  = \dfrac{11}{28} = 0.3929$
#
# $t = \displaystyle P\left( Y>2, X < 1 \right) = \int_{- \infty}^1 {dx\int_{2}^{\infty} {f\left( {x,y} \right)dy} }  = \dfrac{33}{112} = 0.2946$
# <span style="float: right;">0.5đ</span>
#
# $p = \dfrac{t}{m} = \dfrac{3}{4}$
# ```mathematica
# m = Integrate[f[x, y], {x, -Infinity, 1}, {y, -Infinity, Infinity}]
# m // N
#
# g[x_, y_] := If[x <= 1 && y >= 2, f[x, y], 0]
# t = Integrate[g[x, y], {x, -Infinity, Infinity}, {y, -Infinity, Infinity}]
# t // N
#
# p = t/m
# ```

# %% [markdown]
# ## Câu 4 (2.5đ)
# * Điểm Toeic trung bình $= EX$, có khoảng tin cậy
# <span style="float: right;">0.5đ</span>
# $$
# \left( {\overline x  - {t_0}\frac{s'}{{\sqrt {n} }},\;\overline x  + {t_0}\frac{s'}{{\sqrt {n} }}} \right)
# $$
#
# * Bảng giá trị<span style="float: right;">0.5đ</span>
#
# <center>
#
# | $X$ | 460 | 480 | 500 | 525 | 570 |
# | :-: | :-: | :-: | :-: | :-: | :-: |
# | $n_i$ | 4 | 15 | 13 | 12 | 6 |
# </center>
#
# $\overline x = 505.2$
# ```mathematica
# X = Join[
#   Table[460, {4 }],
#   Table[480, {15}],
#   Table[500, {13}],
#   Table[525, {12}],
#   Table[570, {6 }]
#   ]
#
# xNg = Mean[X] // N
# ```
#
# * $s'= 31.2815$
# <span style="float: right;">0.5đ</span>
# ```mathematica
# sDc = StandardDeviation[X] // N
# ```
#
# * $t_0 = t_{1-\gamma}^{n-1} = t_{1 - 85\%}^{50-1} = 1.4625$
# <span style="float: right;">0.5đ</span>
# ```mathematica
# t0 = -Quantile[StudentTDistribution[n - 1], 0.15/2]
# ```
#
# * Khoảng tin cậy cần tìm là $\left(498.73,\; 511.67\right)$
# <span style="float: right;">0.5đ</span>
# ```mathematica
# xNg - t0*sDc/Sqrt[n]
# xNg + t0*sDc/Sqrt[n]
# ```

# %% [markdown]
# ## Câu 5 (2.5đ)
# * Đặt $A = $ {sinh viên bị điểm F}. Bài toán kiểm định
# <span style="float: right;">0.5đ</span>
# $$
# {H_0}:P\left( A \right) = 0.3,\quad {H_1}:P\left( A \right) > 0.3,\quad\alpha  = 1\%
# $$
#
# * ${z_{qs}} = \dfrac{{\dfrac{m}{n} - {p_0}}}{{\sqrt {{p_0}\left( {1 - {p_0}} \right)} }}\sqrt n  = \dfrac{{\dfrac{{62}}{{200}} - 0.3}}{{\sqrt {0.3 \times \left( {1 - 0.3} \right)} }}\sqrt {200}  = 0.3086$
# <span style="float: right;">0.5đ + 0.5đ</span>
# ```mathematica
# n = 200
# m = 62
# p0 = 0.3
#
# zQs = (m/n - p0)/Sqrt[p0 (1 - p0)]*Sqrt[n]
# ```
# * $\varPhi \left( {{z_0}} \right) = 1 - \alpha  = 0.99 \Rightarrow {z_0} = 2.3264$
# <span style="float: right;">0.5đ</span>
# ```mathematica
# z0 = Quantile[NormalDistribution[0, 1], 0.99]
# ```
#
# * $z_{qs} < z_0\Rightarrow$ chấp nhận $H_0$ (bác bỏ $H_1$), tức là tỷ lệ điểm F năm nay không cao hơn các năm trước.
# <span style="float: right;">0.5đ</span>
